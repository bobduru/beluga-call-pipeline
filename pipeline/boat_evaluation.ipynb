# %%
from dotenv import load_dotenv
from pathlib import Path
import sys
import os

# Walk up until we find the project root (folder with the .env)
current_path = Path().resolve()
for parent in [current_path] + list(current_path.parents):
    if (parent / ".env").exists():
        load_dotenv(parent / ".env")
        project_root = os.getenv("PROJECT_ROOT")
        print(project_root)
        sys.path.append(project_root)     
        break


# %load_ext autoreload
# %autoreload 2
# Out:
# C:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\

# %%
import torch
import matplotlib.pyplot as plt
from datetime import timedelta

import numpy as np

import matplotlib.pyplot as plt

import time
from tqdm import tqdm
from datetime import datetime
import os
from data_preprocessing.spectrogram.spectrogram_generator import SPECT_GENERATOR, HYDROPHONE_SENSITIVITY
import pandas as pd
from models.quant_mobilenet import load_mobilenet_v3_quant_from_file
from data_preprocessing.spectrogram.spectrogram_generator import SpectrogramGenerator
from pipeline import classify, run_pipeline_batched_long_spects,get_audio_start_time, get_hydrophone_model

from vizualization import plot_pipeline_outputs_on_spects, analyze_pipeline_performance

from models.utils import get_best_device
# %load_ext autoreload
# %autoreload 2

# Set pandas display options to show full dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None) 
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Running the Pipeline on a Single Audio File
#
#  This notebook demonstrates how to:
#  1. Process a single audio file through the classification pipeline
#  2. Visualize the detected calls on spectrograms for verification
#
#
#  For processing multiple files in parallel, see `run_pipeline_parallel.py`

# %% [markdown]
# ### Loading the model and the spectrogram generator:

# %%
model = load_mobilenet_v3_quant_from_file("../models/weights/mobile_net_8_layers_qat.pt", n_layers=8)

device = get_best_device()
model.to(device)
model.eval()

#spectrogram generator the model was trained on
spect_generator = SpectrogramGenerator(
        n_fft=2048,
        hop_length=1024,
        n_mels=64,
        fmin=200,
        sample_rate=192000, 
    )
# Out:
# C:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\models\quant_mobilenet.py:85: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")

# %% [markdown]
# ### Loading the file we want to process

# %%
def translate_to_raven(results_df, sample_rate):
    # Create new dataframe with Raven format columns
    raven_df = pd.DataFrame()
    raven_df["Selection"] = [x + 1 for x in results_df.index.tolist()]
    raven_df["View"] = "Spectrogram 1"
    raven_df["Channel"] = 1
    # Begin Time is seconds since start
    raven_df["Begin Time (s)"] = results_df["seconds_since_file_start"]
    
    # End Time is Begin Time + 1 second window
    raven_df["End Time (s)"] = results_df["seconds_since_file_start"] + 1.0
    
    # Low Freq is 0 Hz
    raven_df["Low Freq (Hz)"] = 0.0
    
    # High Freq is Nyquist frequency (sample_rate/2)
    raven_df["High Freq (Hz)"] = sample_rate / 2

    raven_df["ECHO"] = results_df["ECHO"]
    raven_df["HFPC"] = results_df["HFPC"]
    raven_df["BBPC"] = results_df["CC"]
    raven_df["Whistle"] = results_df["Whistle"]

    raven_df["GROUNDTRUTH"] = ""
    raven_df["DETAILS"] = ""
    raven_df["Notes"] = ""
    
    return raven_df

# %%
def clip_and_save_audio(long_audio, sample_rate, start_s, end_s, output_filename, dir="./"):
    """
    Clip a segment from audio and save it to a file.
    
    Parameters:
    -----------
    long_audio : np.ndarray
        The full audio array (float32 from librosa)
    sample_rate : int
        Sample rate of the audio (Hz)
    start_s : float
        Start time in seconds
    end_s : float
        End time in seconds
    output_filename : str
        Filename to save the clipped audio file (should end with .wav)
    dir : str
        Directory to save the file (default: "./")
    
    Returns:
    --------
    np.ndarray
        The clipped audio segment
    """
    import soundfile as sf
    import os
    
    # Convert times to sample indices
    start_sample = int(start_s * sample_rate)
    end_sample = int(end_s * sample_rate)
    
    # Clip the audio
    clipped_audio = long_audio[start_sample:end_sample]
    
    # Ensure directory exists
    output_dir = os.path.abspath(dir)
    os.makedirs(output_dir, exist_ok=True)
    filepath = os.path.join(output_dir, output_filename)
    
    # Save using soundfile - handles float32 properly for all audio software
    sf.write(filepath, clipped_audio, sample_rate)
    
    duration = end_s - start_s
    print(f"Saved {duration:.2f}s audio clip to: {filepath}")
    print(f"Clip shape: {clipped_audio.shape}, Sample rate: {sample_rate} Hz")
    
    return clipped_audio

# %%
def create_snippet_df( raven_df, filename, start_s, end_s, boat_labeling_file, boat_labeling_file_id):
    audio_start_time = get_audio_start_time(filename)
    hydrophone_model = get_hydrophone_model(filename)

    snippet_df = raven_df[
            (raven_df["Begin Time (s)"] >= start_s) & 
            (raven_df["Begin Time (s)"] < end_s)
        ].copy()

    snippet_df["Begin Time (s)"] = snippet_df["Begin Time (s)"] - start_s
    snippet_df["End Time (s)"] = snippet_df["End Time (s)"] - start_s

    snippet_start_time = audio_start_time + pd.to_timedelta(start_s, unit="s")
    # Format snippet_start_time to create the date string in the filename (YYMMDDHHMMSS)
    snippet_date_str = snippet_start_time.strftime("%y%m%d%H%M%S")

    snippet_filename = f"{hydrophone_model}.{snippet_date_str}.snippet.wav"

    snippet_df["original_filename"] = filename
    snippet_df["snippet_filename"] = snippet_filename
    snippet_df["snippet_start_time"] = snippet_start_time
    snippet_df["snippet_start_s"] = start_s
    snippet_df["snippet_end_s"] = end_s
    snippet_df["boat_labeling_file"] = boat_labeling_file
    snippet_df["boat_labeling_file_id"] = boat_labeling_file_id

    # calls_detected = snippet_df["ECHO"].sum() + snippet_df["HFPC"].sum() + snippet_df["BBPC"].sum() + snippet_df["Whistle"].sum()

    calls_detected = {
        "ECHO": snippet_df["ECHO"].sum(),
        "HFPC": snippet_df["HFPC"].sum(),
        "BBPC": snippet_df["BBPC"].sum(),
        "Whistle": snippet_df["Whistle"].sum()
    }

    return snippet_df, snippet_filename, calls_detected

# %% [markdown]
# ## Running the pipeline on the files that were labeled

# %%
from pipeline import run_multi_file_pipeline_with_prefetching


def run_pipeline_subset(file_subset, raw_dir, out_dir,  process_index):

    spect_generator = SpectrogramGenerator(
            n_fft=2048,
            hop_length=1024,
            n_mels=64,
            fmin=200,
            sample_rate=192000, 
        )

    return run_multi_file_pipeline_with_prefetching(
        file_subset,
        raw_dir,
        out_dir,
        spect_generator,
        process_index=process_index,
        filter_absences=False
    )

# %%
labels_folder = "../data/Labels_boats/"
# site = "KAM_2020"
# wavs_folder = "G:/KAM/WAV files/"
# out_dir = "./outputs/KAM_2020/"

# site = "BSM_2017"
# wavs_folder = "D:/BSM 2017/"
# out_dir = "./outputs/BSM_2017/"
site = "CAC_2021"
wavs_folder = "G:/CAC_2021/"
out_dir = "./outputs/CAC_2021/"

import os

label_files = []
labels_path = os.path.join(labels_folder, site)
for fname in os.listdir(labels_path):
    if fname.endswith(".txt"):
        # file_path = os.path.join(labels_path, fname)
        label_files.append(fname)

label_files

wav_files = []
for label_file in label_files:
    wav_file = label_file.replace(".Table.1.selections.txt", ".wav")
    wav_files.append(wav_file)

wav_files
201359382.210804135949
# Out:
# 201359382.21080413

# %%
wav_files = wav_files[-9:]
wav_files
# Out:
# ['201359382.210804135949.wav',
#  '201359382.210804152948.wav',
#  '201359382.210805075958.wav',
#  '201359382.210805135950.wav',
#  '201359382.210805152949.wav',
#  '201359382.210805165948.wav',
#  '201359382.210805182948.wav',
#  '201359382.210806105952.wav',
#  '201359382.210807092953.wav']

# %%
run_pipeline_subset(wav_files, wavs_folder, out_dir, 0)
# Out:
# C:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\models\quant_mobilenet.py:85: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location="cpu")
# C:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data_preprocessing\spectrogram\spectrogram_generator.py:339: FutureWarning: PySoundFile failed. Trying audioread instead.
# 	Audioread support is deprecated in librosa 0.10.0 and will be removed in version 1.0.
#   original_sr = librosa.get_samplerate(audio_path)
# WARNING no noise spect found
# [Thread 0] Processing 201359382.210804135949.wav : 1/9:   0%|          | 0/1 [00:00<?, ?it/s]
# Error processing 201359382.210804135949.wav: 'Timestamp'
# Skipping 201359382.210804152948.wav due to loading error
# Skipping 201359382.210805075958.wav due to loading error
# Skipping 201359382.210805135950.wav due to loading error
# Skipping 201359382.210805152949.wav due to loading error
# Skipping 201359382.210805165948.wav due to loading error
# Skipping 201359382.210805182948.wav due to loading error
# Skipping 201359382.210806105952.wav due to loading error
# Skipping 201359382.210807092953.wav due to loading error
# Completed processing 0/9 files
# C:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data_preprocessing\spectrogram\spectrogram_generator.py:339: FutureWarning: PySoundFile failed. Trying audioread instead.
# 	Audioread support is deprecated in librosa 0.10.0 and will be removed in version 1.0.
#   original_sr = librosa.get_samplerate(audio_path)
# 0

# %% [markdown]
# ## Exporting the file snippets

# %%
# file_of_interest = "5725.200801155954"

# site = "KAM"

# if site == "KAM":
#     wavs_folder = "G:/KAM/WAV files/"
#     site_year = "KAM_2020"
# elif site == "BSM":
#     wavs_folder = "D:/BSM 2017/"
#     site_year = "BSM_2017"
# elif site == "CAC":
#     wavs_folder = "G:/CAC_2021/"
#     site_year = "CAC_2021"


# audio_file = file_of_interest+".wav"
# audio_file_path = wavs_folder + audio_file


# # print(audio_start_time)
# long_audio, sample_rate, original_sr = spect_generator.load_audio(audio_file_path)

# %%
# results_df = pd.read_csv(f"./outputs/{site_year}/{file_of_interest}.csv")
# raven_df = translate_to_raven(results_df, sample_rate)
# Out:
#                 Timestamp  seconds_since_file_start   noise_calc_method  \
# 0     2020-08-01 15:59:58                       4.0  precise_with_model
# 1     2020-08-01 15:59:59                       5.0  precise_with_model
# 2     2020-08-01 16:00:00                       6.0  precise_with_model
# 3     2020-08-01 16:00:01                       7.0  precise_with_model
# 4     2020-08-01 16:00:02                       8.0  precise_with_model
# 5     2020-08-01 16:00:03                       9.0  precise_with_model
# 6     2020-08-01 16:00:04                      10.0  precise_with_model
# 7     2020-08-01 16:00:05                      11.0  precise_with_model
# 8     2020-08-01 16:00:06                      12.0  precise_with_model
# 3371                            1                     9.39
# 3372                            1                    14.92
# 3373                            1                     9.20
# 3374                            1                     7.66
# 3375                            1                     6.54
# 3376                            1                     7.17
# 3377                            1                     8.06
# 3378                            1                     6.58
# 3379                            1                     7.56
# 3380                            1                     7.64
# 3381                            1                     8.12
# 3382                            1                     6.81
# 3383                            1                     7.92
# 3384                            1                    13.11
# 3385                            1                    12.59
# 3386                            1                    11.27
# 3387                            1                     9.99
# 3388                            0                     6.99
# 3389                            0                     5.89
# 3390                            1                     8.82
# 3391                            1                     8.37
# 3392                            1                    15.95
# 3393                            1                     6.75
# 3394                            1                     8.78
# 3395                            1                     8.23
# 3396                            1                    10.62
# 3397                            1                     9.06
# 3398                            1                    10.55
# 3399                            1                     6.66
# 3400                            0                     6.14
# 3401                            1                     8.12
# 3402                            1                     9.51
# 3403                            1                     9.12
# 3404                            1                     9.06
# 3405                            1                     7.94
# 3406                            1                     6.90
# 3407                            1                     7.14
# 3408                            1                     7.05
# 3409                            1                     7.33
# 3410                            1                     9.36
# 3411                            1                     8.10
# 3412                            0                     5.43
# 3413                            1                     9.95
# 3414                            1                    14.58
# 3415                            1                     8.62
# 3416                            1                     7.49
# 3417                            1                     7.31
# 3418                            1                     6.51
# 3419                            1                     9.44
# 3420                            1                     7.36
# 3421                            1                    10.03
# 3422                            1                     8.04
# 3423                            1                     8.00
# 3424                            1                     9.35
# 3425                            1                     6.95
# 3426                            1                    10.33
# 3427                            1                    10.66
# 3428                            1                    15.14
# 3429                            1                    10.95
# 3430                            1                     6.54
# 3431                            1                     6.35
# 3432                            1                     9.99
# 3433                            1                     7.92
# 3434                            1                     6.94
# 3435                            1                     6.79
# 3436                            1                     6.06
# 3437                            1                     6.39
# 3438                            1                     6.68
# 3439                            1                     6.70
# 3440                            1                    10.95
# 3441                            1                     9.62
# 3442                            1                     8.96
# 3443                            1                    10.19
# 3444                            1                    12.81
# 3445                            1                    11.48
# 3446                            1                     6.50
# 3447                            1                     6.50
# 3448                            1                     8.16
# 3449                            1                    10.09
# 3450                            1                     9.92
# 3451                            1                     8.51
# 3452                            1                     9.85
# 3453                            1                     9.15
# 3454                            1                    11.34
# 3455                            1                    11.99
# 3456                            1                     9.23
# 3457                            1                    10.37
# 3458                            1                    10.28
# 3459                            1                     9.16
# 3460                            1                     8.33
# 3461                            1                    12.66
# 3462                            1                     8.75
# 3463                            1                     7.55
# 3464                            1                     5.99
# 3465                            1                     8.47
# 3466                            1                    12.30
# 3467                            1                     7.48
# 3468                            1                    10.10
# 3469                            1                     8.50
# 3470                            1                     8.19
# 3471                            1                     8.09
# 3472                            1                     5.92
# 3473                            1                     9.23
# 3474                            0                     5.98
# 3475                            0                     7.18
# 3476                            0                     5.64
# 3477                            1                     7.62
# 3478                            1                     8.98
# 3479                            0                     0.00
# 3480                            0                     7.36
# 3481                            1                     9.13
# 3482                            1                    13.75
# 3483                            1                    10.88
# 3484                            0                     8.16
# 3485                            1                     7.00
# 3486                            1                     6.13
# 3487                            0                     7.32
# 3488                            1                     7.87
# 3489                            1                    11.93
# 3490                            1                    12.23
# 3491                            1                     7.68
# 3492                            1                     8.54
# 3493                            1                     8.12
# 3494                            1                     8.85
# 3495                            1                    10.40
# 3496                            1                    11.50
# 3497                            1                     9.25
# 3498                            1                     8.43
# 3499                            1                     9.56
# 3500                            1                     8.85
# 3501                            0                     6.44
# 3502                            1                     6.57
# 3503                            1                     6.51
# 3504                            1                     8.27
# 3505                            1                    12.74
# 3506                            1                    17.80
# 3507                            1                    14.84
# 3508                            1                     8.93
# 3509                            1                    10.03
# 3510                            1                    11.66
# 3511                            1                     7.35
# 3512                            1                     7.57
# 3513                            1                     9.92
# 3514                            1                    12.17
# 3515                            1                    11.03
# 3516                            1                    13.59
# 3517                            1                    14.31
# 3518                            1                    11.93
# 3519                            1                    10.21
# 3520                            0                    10.63
# 3521                            1                    11.27
# 3522                            0                     8.50
# 3523                            1                     7.41
# 3524                            1                    10.30
# 3525                            1                    12.90
# 3526                            1                    10.93
# 3527                            1                     7.59
# 3528                            1                     9.19
# 3529                            1                    10.62
# 3530                            1                    10.62
# 3531                            1                     8.32
# 3532                            1                     9.24
# 3533                            1                     9.39
# 3534                            1                     8.90
# 3535                            1                    10.02
# 3536                            1                     8.09
# 3537                            1                     7.31
# 3538                            1                    10.42
# 3539                            1                    15.33
# 3540                            1                    10.14
# 3541                            1                    11.47
# 3542                            1                    11.96
# 3543                            1                    10.31
# 3544                            1                     9.64
# 3545                            1                    10.59
# 3546                            1                    11.08
# 3547                            1                     8.38
# 3548                            1                     9.92
# 3549                            1                    11.15
# 3550                            1                     8.45
# 3551                            1                     7.41
# 3552                            1                     9.32
# 3553                            1                    11.73
# 3554                            0                     6.97
# 3555                            1                    11.13
# 3556                            0                     7.56
# 3557                            1                     9.57
# 3558                            1                     9.60
# 3559                            0                     6.75
# 3560                            1                     7.51
# 3561                            1                     9.18
# 3562                            1                     7.88
# 3563                            0                     7.62
# 3564                            1                    10.32
# 3565                            1                    14.43
# 3566                            0                     6.75
# 3567                            1                     6.51
# 3568                            0                     5.65
# 3569                            0                     7.76
# 3570                            1                     7.76
# 3571                            1                     9.21
# 3572                            1                    11.28
# 3573                            1                     6.75
# 3574                            1                    10.75
# 3575                            1                    15.32
# 3576                            1                     7.71
# 3577                            1                     8.84
# 3578                            1                    12.26
# 3579                            1                     7.92
# 3580                            1                     9.79
# 3581                            1                    10.38
# 3582                            1                     6.97
# 3583                            1                     6.78
# 3584                            1                    11.23
# 3585                            1                     7.16
# 3586                            1                    11.69
# 3587                            1                     9.40
# 3588                            1                    11.45
# 3589                            1                     9.83
# 3590                            1                     9.66
# 3591                            0                     0.00
# 3592                            1                    11.53
# 3593                            1                     9.83
# 3594                            1                     9.24

# %%
# Save to tab-delimited file

# %%
# boat_labeling_file = f"{file_of_interest}.Table.1.selections.txt"
# boat_labels = pd.read_csv(f"{labels_folder}/{site_year}/{boat_labeling_file}", sep="\t")
# boat_labels["Begin Time (s)"] = boat_labels["Begin Time (s)"].round(0).astype(int)
# boat_labels["End Time (s)"] = boat_labels["End Time (s)"].round(0).astype(int)

# %%
# snippet_dir = f"../data/evaluation_snippets/v2/{site_year}/"

# %%
# passage_id = 1
# passage_start_s = boat_labels.loc[boat_labels["Selection"] == passage_id, "Begin Time (s)"].values[0]
# passage_end_s = boat_labels.loc[boat_labels["Selection"] == passage_id, "End Time (s)"].values[0]
# context = boat_labels.loc[boat_labels["Selection"] == 1, "Type"].values[0]
# print(f"Passage {passage_id}: {passage_start_s}s to {passage_end_s}s, context: {context}, length: {passage_end_s - passage_start_s}s")
# Out:
# Passage 1: 186s to 299s, context: Boat, length: 113s

# %%
# start_s = passage_start_s 
# end_s = passage_end_s

# passage_df, snippet_filename = create_snippet_df(raven_df, audio_file, start_s, end_s, boat_labeling_file, passage_id)
# passage_df["context"] = context


# clip_and_save_audio(long_audio, sample_rate, start_s, end_s, snippet_filename, snippet_dir)

# labels_filename = snippet_filename.replace(".wav", ".selections.txt")
# passage_df.to_csv(snippet_dir + labels_filename, sep="\t", index=False)
# Out:
# Saved 113.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\5725.200801160300.snippet.wav
# Clip shape: (21696000,), Sample rate: 192000 Hz

# %%
# Out:
# Interrupted — exiting processing loop early.

# %% [markdown]
# # Merging everything

# %%
labels_root = "../data/Labels_boats/"
out_fp = "../data/Labels_boats/labels_boats_merged.csv"
dfs = []
master_columns = None

for site_year in os.listdir(labels_root):
    site_path = os.path.join(labels_root, site_year)
    if not os.path.isdir(site_path):
        continue

    for fname in os.listdir(site_path):
        if not fname.endswith(".txt"):
            continue

        file_path = os.path.join(site_path, fname)

        # Read file raw
        df = pd.read_csv(file_path, sep="\t")

        # First file defines the canonical schema
        if master_columns is None:
            master_columns = df.columns.tolist()
        else:
            # Drop repeated header rows accidentally parsed as data
            df = df[df[df.columns[0]] != master_columns[0]]

        # Add metadata
        df["site_year"] = site_year
        df["source_label_file"] = fname

        dfs.append(df)

# Merge everything
labels_boats_merged = pd.concat(dfs, ignore_index=True)

labels_boats_merged["Begin Time (s)"] = labels_boats_merged["Begin Time (s)"].round(0).astype(int)
labels_boats_merged["End Time (s)"] = labels_boats_merged["End Time (s)"].round(0).astype(int)
labels_boats_merged["duration_s"] = labels_boats_merged["End Time (s)"] - labels_boats_merged["Begin Time (s)"]
labels_boats_merged.loc[labels_boats_merged["Type"] == "Empty", "Type"] = "Ambient"

labels_boats_merged = labels_boats_merged.dropna()
# # Save clean CSV
# os.makedirs(os.path.dirname(out_fp), exist_ok=True)
# labels_boats_merged.to_csv(out_fp, index=False)

# print(f"Merged dataset saved to: {out_fp}")
# print(f"Total rows: {len(labels_boats_merged)}")

# %%
labels_boats_merged.head(5)
labels_boats_merged["duration_s"].describe()
# Out:
# count     154.000000
# mean      763.012987
# std       520.903890
# min        98.000000
# 25%       384.500000
# 50%       682.500000
# 75%       990.000000
# max      3924.000000
# Name: duration_s, dtype: float64

# %%
labels_boats_merged["Type"].value_counts(dropna=False)
# Out:
# Type
# Boat       77
# Ambient    77
# Name: count, dtype: int64

# %%
# labels_boats_merged = labels_boats_merged[labels_boats_merged["Begin File"] == "201359382.210714075958.wav"]

# %%
def create_passage_snippets(passage_start_s, passage_end_s, min_duration_s=240, snippet_duration_s=120, max_snippets=3):
    """
    Create snippet time ranges from a passage based on its duration.
    
    Args:
        passage_start_s: Start time of the passage in seconds
        passage_end_s: End time of the passage in seconds
        min_duration_s: Minimum duration to split into snippets (default 4 minutes = 240 seconds)
        snippet_duration_s: Duration of each snippet (default 2 minutes = 120 seconds)
        max_snippets: Maximum number of snippets to create (default 5)
    
    Returns:
        List of tuples (start_s, end_s) representing snippet time ranges
    
    Examples:
        - 3 minutes (180s): returns whole passage as 1 snippet
        - 5 minutes (300s): returns 2 snippets of 2 minutes each
        - 8 minutes (480s): returns 3 snippets of 2 minutes each, evenly distributed
        - 50 minutes (3000s): returns 5 snippets of 2 minutes each, evenly distributed
    """
    duration_s = passage_end_s - passage_start_s
    
    # If duration is shorter than minimum, return the whole passage
    if duration_s < min_duration_s:
        return [(passage_start_s, passage_end_s)]
    
    # Calculate number of snippets (capped at max_snippets)
    num_snippets = min(max_snippets, int(duration_s // snippet_duration_s))
    
    # If we only have 1 snippet, return the whole passage
    if num_snippets <= 1:
        end_s = passage_start_s + snippet_duration_s
        return [(passage_start_s, min(end_s, passage_end_s))]
    
    # Distribute snippets evenly across the passage
    # Available range for snippet start positions
    available_range = duration_s - snippet_duration_s
    
    snippets = []
    for i in range(num_snippets):
        # Calculate start position: evenly distributed from beginning to end
        start_offset = (i / (num_snippets - 1)) * available_range
        start_s = passage_start_s + start_offset
        end_s = start_s + snippet_duration_s

        start_s = round(start_s)
        end_s = round(end_s)
        snippets.append((start_s, end_s))
    
    return snippets

# %%
create_passage_snippets(0, 800, max_snippets=3)
# Out:
# [(0, 120), (340, 460), (680, 800)]

# %%
labels_boats_merged.head(5)
# Out:
#    Selection           View  Channel  Begin Time (s)  End Time (s)  \
# 0          1  Spectrogram 1        1            1035          1551
# 1          2  Spectrogram 1        1               0           912
# 2          1  Spectrogram 1        1             161           686
# 4          1  Spectrogram 1        1            1993          2311
# 5          2  Spectrogram 1        1            1209          1725
#
#    High Freq (Hz)  Low Freq (Hz)           Begin Date Time  Delta Time (s)  \
# 0       61166.144            0.0   2017/7/24  9:47:16.9044        515.9344
# 1      144000.000            0.0   2017/7/24  9:30:02.0000        912.1102
# 2       45113.900            0.0  2017/7/24  10:32:43.3788        525.1063
# 4       30039.700            0.0  2017/7/24  12:03:15.3663        318.0901
# 5       61166.100            0.0  2017/7/24  11:50:11.3403        515.7655
#
#                    Begin File     Type site_year  \
# 0  201359382.170724093002.wav     Boat  BSM_2017
# 1  201359382.170724093002.wav  Ambient  BSM_2017
# 2  201359382.170724103002.wav     Boat  BSM_2017
# 4  201359382.170724113002.wav     Boat  BSM_2017
# 5  201359382.170724113002.wav     Boat  BSM_2017
#
#                                source_label_file  duration_s
# 0  201359382.170724093002.Table.1.selections.txt         516
# 1  201359382.170724093002.Table.1.selections.txt         912
# 2  201359382.170724103002.Table.1.selections.txt         525
# 4  201359382.170724113002.Table.1.selections.txt         318
# 5  201359382.170724113002.Table.1.selections.txt         516

# %%
snippet_dir = f"../data/evaluation_snippets/v2/"

# wavs_folder_dict = {
#     "KAM_2020": "G:/KAM/WAV files/",
#     "BSM_2017": "D:/BSM 2017/",
#     "CAC_2021": "/Users/emmanuel/Documents/belugas/beluga-call-pipeline/data/CAC_2021_Labels_Ship/"
# }
wavs_folder_dict = {
    "KAM_2020": "G:/KAM/WAV files/",
    "BSM_2017": "D:/BSM 2017/",
    "CAC_2021": "G:/CAC_2021/"
}

# snippets_df = pd.DataFrame(columns=["site_year", "snippet_filename", "pipeline_output_file", "source_wav_file", "source_label_file", "context", "source_label_passage_id", "original_start_s", "original_end_s", "snippet_passage_timing", "n_calls_detected", "labeled"])
snippets_list = []

for (site_year, audio_file), group_df in labels_boats_merged.groupby(["site_year", "Begin File"]):

    # if site_year == "BSM_2017":
    #     continue
    num_boats = (group_df["Type"] == "Boat").sum()
    num_ambients = (group_df["Type"] == "Ambient").sum()
    print(f"Processing {site_year} {audio_file}, {len(group_df)} passages, {num_boats} boats, {num_ambients} ambients")
    file_of_interest = audio_file.replace(".wav", "")
    


    wavs_folder = wavs_folder_dict[site_year]

    audio_file_path = wavs_folder + audio_file

    if not os.path.exists(audio_file_path):
        print(f"Audio file {audio_file_path} does not exist. Skipping...")
        continue
    # print(audio_start_time)
    long_audio, sample_rate, original_sr = spect_generator.load_audio(audio_file_path) 


    pipeline_output_path =f"./outputs/{site_year}/{file_of_interest}.csv"
    if not os.path.exists(pipeline_output_path):
        print(f"Outputs file {pipeline_output_path} does not exist. Skipping...")
        continue
    results_df = pd.read_csv(pipeline_output_path)
    raven_df = translate_to_raven(results_df, sample_rate)


    for i, row in group_df.iterrows():
        print(row["Type"])
        passage_id = row["Selection"]
        passage_start_s = row["Begin Time (s)"]
        passage_end_s = row["End Time (s)"]
        context = row["Type"]
        boat_labeling_file = row["source_label_file"]

        cur_snippet_dir = f"../data/evaluation_snippets/v2/{site_year}/{context}/"
        os.makedirs(cur_snippet_dir, exist_ok=True)

        duration_s = passage_end_s - passage_start_s

        #Only take 1 snippet for ambient
        max_snippets = 3 if context == "Boat" else 1

        snippets = create_passage_snippets(passage_start_s, passage_end_s, max_snippets=max_snippets)
        print(f"passage is {duration_s}s long, {len(snippets)} snippets")
        print(snippets)
        for i, (start_s, end_s) in enumerate(snippets):
            passage_df, snippet_filename, calls_detected = create_snippet_df(raven_df, audio_file, start_s, end_s, boat_labeling_file, passage_id)
            passage_df["context"] = context

            print("calls detected", calls_detected)
            clip_and_save_audio(long_audio, sample_rate, start_s, end_s, snippet_filename, cur_snippet_dir)

            pipeline_output_file = snippet_filename.replace(".wav", ".selections.txt")
            

            passage_timings = ["Start", "Middle", "End"]

            if start_s == passage_start_s and end_s == passage_end_s:
                passage_timing = "Full_Passage"
            else:
                # If we have 2 snippets, the first is "Start" and the second is "End"
                if len(snippets) == 2:
                    passage_timing = "Start" if i == 0 else "End"
                else:
                    passage_timing = passage_timings[i]
            
            

            snippets_df = snippets_list.append({
                "site_year": site_year,
                "snippet_filename": snippet_filename,
                "pipeline_output_file": pipeline_output_file,
                "snippet_duration_s": end_s - start_s,
                "context": context,
                "ECHO_calls": calls_detected["ECHO"],
                "HFPC_calls": calls_detected["HFPC"],
                "BBPC_calls": calls_detected["BBPC"],
                "Whistle_calls": calls_detected["Whistle"],
                "source_wav_file": audio_file,
                "source_label_file": boat_labeling_file,
                "snippet_start_s": start_s,
                "snippet_end_s": end_s,
                
                "snippet_passage_timing": passage_timing,

                "passage_start_s": passage_start_s,
                "passage_end_s": passage_end_s,
                "source_label_passage_id": passage_id,
                "unique_passage_id": f"{audio_file}_{passage_id}",
                
                "labeled": False
            })

            passage_df.to_csv(cur_snippet_dir + pipeline_output_file, sep="\t", index=False)

    # break  # Remove or adjust this if you want to process more than one file group

snippets_df = pd.DataFrame(snippets_list)
# Out:
# Processing BSM_2017 201359382.170724093002.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 516s long, 3 snippets
# [(1035, 1155), (1233, 1353), (1431, 1551)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 3}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724094717.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724095035.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724095353.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 912s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170724093002.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170724103002.wav, 1 passages, 1 boats, 0 ambients
# Boat
# passage is 525s long, 3 snippets
# [(161, 281), (364, 484), (566, 686)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724103243.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724103606.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 8, 'HFPC': 0, 'BBPC': 9, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724103928.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170724113002.wav, 2 passages, 2 boats, 0 ambients
# Boat
# passage is 318s long, 2 snippets
# [(1993, 2113), (2191, 2311)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724120315.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724120633.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 516s long, 3 snippets
# [(1209, 1329), (1407, 1527), (1605, 1725)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724115011.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724115329.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724115647.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170724123002.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 654s long, 3 snippets
# [(1206, 1326), (1473, 1593), (1740, 1860)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724125008.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724125435.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 30, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724125902.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 964s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170724123002.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1003s long, 1 snippets
# [(1984, 2104)]
# calls detected {'ECHO': 84, 'HFPC': 2, 'BBPC': 2, 'Whistle': 9}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170724130306.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170724133002.wav, 3 passages, 3 boats, 0 ambients
# Boat
# passage is 337s long, 2 snippets
# [(113, 233), (330, 450)]
# calls detected {'ECHO': 21, 'HFPC': 1, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724133155.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 106, 'HFPC': 5, 'BBPC': 0, 'Whistle': 5}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724133532.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 812s long, 3 snippets
# [(537, 657), (883, 1003), (1229, 1349)]
# calls detected {'ECHO': 41, 'HFPC': 15, 'BBPC': 0, 'Whistle': 4}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724133859.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 88, 'HFPC': 8, 'BBPC': 1, 'Whistle': 3}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724134445.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 54, 'HFPC': 1, 'BBPC': 2, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724135031.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 713s long, 3 snippets
# [(1585, 1705), (1882, 2002), (2178, 2298)]
# calls detected {'ECHO': 85, 'HFPC': 4, 'BBPC': 0, 'Whistle': 5}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724135627.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 88, 'HFPC': 20, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724140124.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 75, 'HFPC': 5, 'BBPC': 7, 'Whistle': 23}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724140620.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170724143002.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 1127s long, 3 snippets
# [(1721, 1841), (2224, 2344), (2728, 2848)]
# calls detected {'ECHO': 3, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724145843.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724150706.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724151530.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 780s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 71, 'HFPC': 5, 'BBPC': 0, 'Whistle': 10}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170724143002.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170724153002.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 484s long, 3 snippets
# [(3045, 3165), (3227, 3347), (3409, 3529)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724162047.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724162349.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170724162651.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 943s long, 1 snippets
# [(1849, 1969)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170724160051.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 871s long, 1 snippets
# [(929, 1049)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170724154531.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170725033002.wav, 3 passages, 2 boats, 1 ambients
# Boat
# passage is 457s long, 3 snippets
# [(272, 392), (440, 560), (609, 729)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725033434.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725033722.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725034011.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 739s long, 3 snippets
# [(2861, 2981), (3170, 3290), (3480, 3600)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725041743.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725042252.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725042802.snippet.wav
# Clip shape: (23014955,), Sample rate: 192000 Hz
# Ambient
# passage is 846s long, 1 snippets
# [(839, 959)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170725034401.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170725043002.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 206s long, 1 snippets
# [(0, 206)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 206.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725043002.snippet.wav
# Clip shape: (39552000,), Sample rate: 192000 Hz
# Ambient
# passage is 995s long, 1 snippets
# [(645, 765)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170725044047.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 898s long, 1 snippets
# [(1790, 1910)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170725045952.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170725053002.wav, 3 passages, 3 boats, 0 ambients
# Boat
# passage is 515s long, 3 snippets
# [(1508, 1628), (1706, 1826), (1903, 2023)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725055510.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725055828.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725060145.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 264s long, 2 snippets
# [(2195, 2315), (2339, 2459)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725060637.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 6, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725060901.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 244s long, 2 snippets
# [(3316, 3436), (3440, 3560)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725062518.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725062722.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170725063002.wav, 3 passages, 2 boats, 1 ambients
# Boat
# passage is 389s long, 3 snippets
# [(1041, 1161), (1176, 1296), (1310, 1430)]
# calls detected {'ECHO': 0, 'HFPC': 1, 'BBPC': 0, 'Whistle': 4}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725064723.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725064938.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725065152.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 358s long, 2 snippets
# [(1877, 1997), (2115, 2235)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725070119.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 25, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725070517.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 770s long, 1 snippets
# [(118, 238)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170725063200.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170725073002.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 269s long, 2 snippets
# [(262, 382), (411, 531)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725073424.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Boat\201359382.170725073653.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 600s long, 1 snippets
# [(730, 850)]
# calls detected {'ECHO': 3, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170725074212.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing BSM_2017 201359382.170725083002.wav, 1 passages, 0 boats, 1 ambients
# Ambient
# passage is 1166s long, 1 snippets
# [(328, 448)]
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\BSM_2017\Ambient\201359382.170725083530.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210714075958.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 690s long, 3 snippets
# [(1856, 1976), (2141, 2261), (2426, 2546)]
# calls detected {'ECHO': 80, 'HFPC': 6, 'BBPC': 5, 'Whistle': 7}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714083054.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 67, 'HFPC': 23, 'BBPC': 2, 'Whistle': 23}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714083539.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 102, 'HFPC': 1, 'BBPC': 5, 'Whistle': 36}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714084024.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 952s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 115, 'HFPC': 26, 'BBPC': 7, 'Whistle': 84}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210714075958.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1104s long, 1 snippets
# [(2752, 2872)]
# calls detected {'ECHO': 55, 'HFPC': 13, 'BBPC': 3, 'Whistle': 87}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210714084550.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210714135951.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 812s long, 3 snippets
# [(4387, 4507), (4733, 4853), (5079, 5199)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714151258.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714151844.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714152430.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1367s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 36}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210714135951.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1310s long, 1 snippets
# [(1419, 1539)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 32}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210714142330.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210714152951.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 918s long, 3 snippets
# [(1730, 1850), (2129, 2249), (2528, 2648)]
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 0, 'Whistle': 6}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714155841.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714160520.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210714161159.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1420s long, 1 snippets
# [(141, 261)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 7}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210714153212.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210715152950.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 412s long, 3 snippets
# [(2461, 2581), (2607, 2727), (2753, 2873)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 5}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210715161051.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210715161317.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 6}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210715161543.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 2263s long, 1 snippets
# [(68, 188)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 5, 'Whistle': 6}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210715153058.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210716075958.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 400s long, 3 snippets
# [(125, 245), (265, 385), (405, 525)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210716080203.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210716080423.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210716080643.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1222s long, 1 snippets
# [(688, 808)]
# calls detected {'ECHO': 11, 'HFPC': 0, 'BBPC': 0, 'Whistle': 18}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210716081126.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1506s long, 1 snippets
# [(2136, 2256)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 25}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210716083534.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210718075958.wav, 1 passages, 1 boats, 0 ambients
# Boat
# passage is 439s long, 3 snippets
# [(3107, 3227), (3266, 3386), (3426, 3546)]
# calls detected {'ECHO': 46, 'HFPC': 0, 'BBPC': 2, 'Whistle': 3}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718085145.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 3, 'HFPC': 0, 'BBPC': 16, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718085424.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 50, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718085704.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210718092953.wav, 1 passages, 1 boats, 0 ambients
# Boat
# passage is 676s long, 3 snippets
# [(2603, 2723), (2881, 3001), (3159, 3279)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 7}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718101316.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 4, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718101754.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718102232.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210718105952.wav, 1 passages, 1 boats, 0 ambients
# Boat
# passage is 766s long, 3 snippets
# [(1663, 1783), (1986, 2106), (2309, 2429)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718112735.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 1, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718113258.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718113821.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210718182950.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 389s long, 3 snippets
# [(3336, 3456), (3470, 3590), (3605, 3725)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718192526.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 3, 'HFPC': 0, 'BBPC': 24, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718192740.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 3, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210718192955.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 945s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 12, 'HFPC': 0, 'BBPC': 0, 'Whistle': 34}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210718182950.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1765s long, 1 snippets
# [(1271, 1391)]
# calls detected {'ECHO': 5, 'HFPC': 0, 'BBPC': 0, 'Whistle': 27}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210718185101.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210719105953.wav, 1 passages, 0 boats, 1 ambients
# Ambient
# passage is 1781s long, 1 snippets
# [(3545, 3665)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 16}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210719115858.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210722075958.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 1494s long, 3 snippets
# [(548, 668), (1235, 1355), (1922, 2042)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 1, 'Whistle': 7}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210722080906.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 2, 'HFPC': 1, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210722082033.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 4, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210722083200.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1474s long, 1 snippets
# [(2195, 2315)]
# calls detected {'ECHO': 5, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210722083633.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210722105951.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 973s long, 3 snippets
# [(627, 747), (1054, 1174), (1480, 1600)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210722111018.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210722111725.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210722112431.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1549s long, 1 snippets
# [(1721, 1841)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210722112832.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210724092954.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 593s long, 3 snippets
# [(3711, 3831), (3948, 4068), (4184, 4304)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210724103145.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 1, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210724103542.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210724103938.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1449s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210724092954.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210725152950.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 504s long, 3 snippets
# [(75, 195), (267, 387), (459, 579)]
# calls detected {'ECHO': 19, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210725153105.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 9, 'HFPC': 0, 'BBPC': 1, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210725153417.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 30, 'HFPC': 0, 'BBPC': 5, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210725153729.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1146s long, 1 snippets
# [(1067, 1187)]
# calls detected {'ECHO': 55, 'HFPC': 0, 'BBPC': 0, 'Whistle': 8}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210725154737.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1601s long, 1 snippets
# [(2475, 2595)]
# calls detected {'ECHO': 62, 'HFPC': 0, 'BBPC': 0, 'Whistle': 34}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210725161105.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210802105951.wav, 2 passages, 1 boats, 1 ambients
# Audio file G:/CAC_2021/201359382.210802105951.wav does not exist. Skipping...
# Processing CAC_2021 201359382.210802182949.wav, 2 passages, 1 boats, 1 ambients
# Boat
# passage is 1180s long, 3 snippets
# [(1987, 2107), (2517, 2637), (3047, 3167)]
# calls detected {'ECHO': 36, 'HFPC': 0, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210802190256.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 32, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210802191146.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 40, 'HFPC': 1, 'BBPC': 0, 'Whistle': 6}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210802192036.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1453s long, 1 snippets
# [(136, 256)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 10}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210802183205.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210803182950.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 836s long, 3 snippets
# [(14, 134), (372, 492), (730, 850)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 10}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210803183004.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 1, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210803183602.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210803184200.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1401s long, 1 snippets
# [(1014, 1134)]
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 0, 'Whistle': 74}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210803184644.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 1354s long, 1 snippets
# [(2540, 2660)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 70}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210803191210.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210804122950.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 392s long, 3 snippets
# [(3419, 3539), (3555, 3675), (3691, 3811)]
# calls detected {'ECHO': 17, 'HFPC': 1, 'BBPC': 0, 'Whistle': 18}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210804132649.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 8, 'HFPC': 0, 'BBPC': 6, 'Whistle': 5}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210804132905.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 3, 'HFPC': 0, 'BBPC': 3, 'Whistle': 17}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Boat\201359382.210804133121.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 967s long, 1 snippets
# [(94, 214)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 98}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210804123124.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 2138s long, 1 snippets
# [(1186, 1306)]
# calls detected {'ECHO': 1, 'HFPC': 1, 'BBPC': 0, 'Whistle': 98}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\CAC_2021\Ambient\201359382.210804124936.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing CAC_2021 201359382.210804135949.wav, 4 passages, 2 boats, 2 ambients
# Outputs file ./outputs/CAC_2021/201359382.210804135949.csv does not exist. Skipping...
# Processing CAC_2021 201359382.210804152948.wav, 3 passages, 1 boats, 2 ambients
# Audio file G:/CAC_2021/201359382.210804152948.wav does not exist. Skipping...
# Processing CAC_2021 201359382.210805075958.wav, 1 passages, 1 boats, 0 ambients
# Audio file G:/CAC_2021/201359382.210805075958.wav does not exist. Skipping...
# Processing CAC_2021 201359382.210805135950.wav, 2 passages, 1 boats, 1 ambients
# Audio file G:/CAC_2021/201359382.210805135950.wav does not exist. Skipping...
# Processing CAC_2021 201359382.210805152949.wav, 3 passages, 2 boats, 1 ambients
# Audio file G:/CAC_2021/201359382.210805152949.wav does not exist. Skipping...
# Processing CAC_2021 201359382.210805165948.wav, 3 passages, 1 boats, 2 ambients
# Audio file G:/CAC_2021/201359382.210805165948.wav does not exist. Skipping...
# Processing CAC_2021 201359382.210805182948.wav, 2 passages, 1 boats, 1 ambients
# Audio file G:/CAC_2021/201359382.210805182948.wav does not exist. Skipping...
# Processing CAC_2021 201359382.210806105952.wav, 3 passages, 1 boats, 2 ambients
# Audio file G:/CAC_2021/201359382.210806105952.wav does not exist. Skipping...
# Processing CAC_2021 201359382.210807092953.wav, 4 passages, 2 boats, 2 ambients
# Audio file G:/CAC_2021/201359382.210807092953.wav does not exist. Skipping...
# Processing KAM_2020 5725.200725175954.wav, 5 passages, 2 boats, 3 ambients
# Boat
# passage is 270s long, 2 snippets
# [(933, 1053), (1083, 1203)]
# calls detected {'ECHO': 72, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200725181527.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 11, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200725181757.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 793s long, 1 snippets
# [(35, 155)]
# calls detected {'ECHO': 64, 'HFPC': 1, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200725180029.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 702s long, 1 snippets
# [(1301, 1421)]
# calls detected {'ECHO': 57, 'HFPC': 1, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200725182135.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 265s long, 2 snippets
# [(2105, 2225), (2250, 2370)]
# calls detected {'ECHO': 30, 'HFPC': 0, 'BBPC': 4, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200725183459.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 65, 'HFPC': 1, 'BBPC': 0, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200725183724.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 190s long, 1 snippets
# [(2395, 2585)]
# calls detected {'ECHO': 92, 'HFPC': 9, 'BBPC': 0, 'Whistle': 14}
# Saved 190.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200725183949.snippet.wav
# Clip shape: (36480000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200725185953.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 149s long, 1 snippets
# [(3199, 3348)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 149.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200725195312.snippet.wav
# Clip shape: (28608000,), Sample rate: 192000 Hz
# Ambient
# passage is 567s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 27, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200725185953.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 713s long, 1 snippets
# [(810, 930)]
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200725191323.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200726185951.wav, 4 passages, 2 boats, 2 ambients
# Boat
# passage is 354s long, 2 snippets
# [(1155, 1275), (1389, 1509)]
# calls detected {'ECHO': 120, 'HFPC': 5, 'BBPC': 8, 'Whistle': 19}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200726191906.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 119, 'HFPC': 3, 'BBPC': 9, 'Whistle': 5}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200726192300.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 247s long, 2 snippets
# [(3314, 3434), (3441, 3561)]
# calls detected {'ECHO': 58, 'HFPC': 0, 'BBPC': 11, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200726195505.snippet.wav
# ...
# Boat
# passage is 527s long, 3 snippets
# [(1446, 1566), (1650, 1770), (1853, 1973)]
# calls detected {'ECHO': 61, 'HFPC': 0, 'BBPC': 3, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200729112403.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 37, 'HFPC': 0, 'BBPC': 21, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200729112727.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 36, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200729113050.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 754s long, 1 snippets
# [(2061, 2181)]
# calls detected {'ECHO': 88, 'HFPC': 0, 'BBPC': 0, 'Whistle': 7}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200729113418.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200729115956.wav, 4 passages, 2 boats, 2 ambients
# Boat
# passage is 167s long, 1 snippets
# [(2329, 2496)]
# calls detected {'ECHO': 66, 'HFPC': 0, 'BBPC': 1, 'Whistle': 1}
# Saved 167.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200729123845.snippet.wav
# Clip shape: (32064000,), Sample rate: 192000 Hz
# Boat
# passage is 160s long, 1 snippets
# [(3439, 3599)]
# calls detected {'ECHO': 29, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 160.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200729125715.snippet.wav
# Clip shape: (30720000,), Sample rate: 192000 Hz
# Ambient
# passage is 694s long, 1 snippets
# [(858, 978)]
# calls detected {'ECHO': 48, 'HFPC': 0, 'BBPC': 0, 'Whistle': 28}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200729121414.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 732s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 12, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200729115956.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200730115956.wav, 3 passages, 2 boats, 1 ambients
# Boat
# passage is 255s long, 2 snippets
# [(469, 589), (604, 724)]
# calls detected {'ECHO': 41, 'HFPC': 0, 'BBPC': 6, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730120745.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 110, 'HFPC': 1, 'BBPC': 1, 'Whistle': 4}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730121000.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 309s long, 2 snippets
# [(1275, 1395), (1464, 1584)]
# calls detected {'ECHO': 113, 'HFPC': 2, 'BBPC': 19, 'Whistle': 5}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730122111.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 100, 'HFPC': 0, 'BBPC': 9, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730122420.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 715s long, 1 snippets
# [(1845, 1965)]
# calls detected {'ECHO': 117, 'HFPC': 4, 'BBPC': 4, 'Whistle': 50}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200730123041.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200730125955.wav, 4 passages, 3 boats, 1 ambients
# Boat
# passage is 279s long, 2 snippets
# [(1039, 1159), (1198, 1318)]
# calls detected {'ECHO': 114, 'HFPC': 5, 'BBPC': 3, 'Whistle': 4}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730131714.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 114, 'HFPC': 1, 'BBPC': 1, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730131953.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 338s long, 2 snippets
# [(1471, 1591), (1689, 1809)]
# calls detected {'ECHO': 72, 'HFPC': 5, 'BBPC': 10, 'Whistle': 1}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730132426.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 86, 'HFPC': 6, 'BBPC': 3, 'Whistle': 6}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730132804.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 348s long, 2 snippets
# [(3252, 3372), (3480, 3600)]
# calls detected {'ECHO': 65, 'HFPC': 0, 'BBPC': 3, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730135407.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 101, 'HFPC': 2, 'BBPC': 0, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200730135755.snippet.wav
# Clip shape: (23010603,), Sample rate: 192000 Hz
# Ambient
# passage is 910s long, 1 snippets
# [(2062, 2182)]
# calls detected {'ECHO': 106, 'HFPC': 12, 'BBPC': 0, 'Whistle': 57}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200730133417.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200731105956.wav, 3 passages, 1 boats, 2 ambients
# Boat
# passage is 198s long, 1 snippets
# [(1782, 1980)]
# calls detected {'ECHO': 106, 'HFPC': 5, 'BBPC': 3, 'Whistle': 1}
# Saved 198.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200731112938.snippet.wav
# Clip shape: (38016000,), Sample rate: 192000 Hz
# Ambient
# passage is 672s long, 1 snippets
# [(0, 120)]
# calls detected {'ECHO': 100, 'HFPC': 6, 'BBPC': 10, 'Whistle': 61}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200731105956.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 791s long, 1 snippets
# [(784, 904)]
# calls detected {'ECHO': 118, 'HFPC': 5, 'BBPC': 2, 'Whistle': 66}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200731111300.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200731135954.wav, 7 passages, 4 boats, 3 ambients
# Boat
# passage is 187s long, 1 snippets
# [(225, 412)]
# calls detected {'ECHO': 182, 'HFPC': 13, 'BBPC': 7, 'Whistle': 6}
# Saved 187.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200731140339.snippet.wav
# Clip shape: (35904000,), Sample rate: 192000 Hz
# Boat
# passage is 98s long, 1 snippets
# [(929, 1027)]
# calls detected {'ECHO': 88, 'HFPC': 5, 'BBPC': 7, 'Whistle': 8}
# Saved 98.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200731141523.snippet.wav
# Clip shape: (18816000,), Sample rate: 192000 Hz
# Boat
# passage is 216s long, 1 snippets
# [(1371, 1587)]
# calls detected {'ECHO': 188, 'HFPC': 2, 'BBPC': 15, 'Whistle': 9}
# Saved 216.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200731142245.snippet.wav
# Clip shape: (41472000,), Sample rate: 192000 Hz
# Boat
# passage is 331s long, 2 snippets
# [(1818, 1938), (2029, 2149)]
# calls detected {'ECHO': 113, 'HFPC': 4, 'BBPC': 0, 'Whistle': 5}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200731143012.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 105, 'HFPC': 2, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200731143343.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 244s long, 1 snippets
# [(589, 709)]
# calls detected {'ECHO': 117, 'HFPC': 4, 'BBPC': 1, 'Whistle': 26}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200731140943.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 390s long, 1 snippets
# [(2614, 2734)]
# calls detected {'ECHO': 119, 'HFPC': 3, 'BBPC': 0, 'Whistle': 13}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200731144328.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 383s long, 1 snippets
# [(3217, 3337)]
# calls detected {'ECHO': 118, 'HFPC': 15, 'BBPC': 13, 'Whistle': 65}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200731145331.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200801095957.wav, 4 passages, 1 boats, 3 ambients
# Boat
# passage is 108s long, 1 snippets
# [(1039, 1147)]
# calls detected {'ECHO': 1, 'HFPC': 0, 'BBPC': 3, 'Whistle': 0}
# Saved 108.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801101716.snippet.wav
# Clip shape: (20736000,), Sample rate: 192000 Hz
# Ambient
# passage is 631s long, 1 snippets
# [(45, 165)]
# calls detected {'ECHO': 20, 'HFPC': 10, 'BBPC': 17, 'Whistle': 51}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801100042.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 673s long, 1 snippets
# [(1275, 1395)]
# calls detected {'ECHO': 17, 'HFPC': 0, 'BBPC': 0, 'Whistle': 27}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801102112.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 641s long, 1 snippets
# [(2958, 3078)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 36}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801104915.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200801145954.wav, 8 passages, 5 boats, 3 ambients
# Boat
# passage is 199s long, 1 snippets
# [(516, 715)]
# calls detected {'ECHO': 105, 'HFPC': 0, 'BBPC': 36, 'Whistle': 6}
# Saved 199.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801150830.snippet.wav
# Clip shape: (38208000,), Sample rate: 192000 Hz
# Boat
# passage is 169s long, 1 snippets
# [(1321, 1490)]
# calls detected {'ECHO': 25, 'HFPC': 0, 'BBPC': 8, 'Whistle': 20}
# Saved 169.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801152155.snippet.wav
# Clip shape: (32448000,), Sample rate: 192000 Hz
# Boat
# passage is 321s long, 2 snippets
# [(1627, 1747), (1828, 1948)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801152701.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801153022.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Boat
# passage is 198s long, 1 snippets
# [(2449, 2647)]
# calls detected {'ECHO': 2, 'HFPC': 0, 'BBPC': 2, 'Whistle': 0}
# Saved 198.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801154043.snippet.wav
# Clip shape: (38016000,), Sample rate: 192000 Hz
# Boat
# passage is 260s long, 2 snippets
# [(2811, 2931), (2951, 3071)]
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801154645.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# calls detected {'ECHO': 0, 'HFPC': 0, 'BBPC': 3, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801154905.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 446s long, 1 snippets
# [(31, 151)]
# calls detected {'ECHO': 104, 'HFPC': 1, 'BBPC': 17, 'Whistle': 31}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801150025.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 439s long, 1 snippets
# [(781, 901)]
# calls detected {'ECHO': 96, 'HFPC': 0, 'BBPC': 2, 'Whistle': 6}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801151255.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 471s long, 1 snippets
# [(3129, 3249)]
# calls detected {'ECHO': 51, 'HFPC': 0, 'BBPC': 0, 'Whistle': 0}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801155203.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Processing KAM_2020 5725.200801155954.wav, 4 passages, 1 boats, 3 ambients
# Boat
# passage is 113s long, 1 snippets
# [(186, 299)]
# calls detected {'ECHO': 51, 'HFPC': 0, 'BBPC': 3, 'Whistle': 1}
# Saved 113.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Boat\5725.200801160300.snippet.wav
# Clip shape: (21696000,), Sample rate: 192000 Hz
# Ambient
# passage is 658s long, 1 snippets
# [(394, 514)]
# calls detected {'ECHO': 95, 'HFPC': 0, 'BBPC': 0, 'Whistle': 11}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801160628.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 624s long, 1 snippets
# [(1160, 1280)]
# calls detected {'ECHO': 116, 'HFPC': 0, 'BBPC': 1, 'Whistle': 2}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801161914.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz
# Ambient
# passage is 687s long, 1 snippets
# [(2819, 2939)]
# calls detected {'ECHO': 119, 'HFPC': 0, 'BBPC': 0, 'Whistle': 3}
# Saved 120.00s audio clip to: c:\Users\Admin\Desktop\Emmanuel\beluga-call-pipeline\data\evaluation_snippets\v2\KAM_2020\Ambient\5725.200801164653.snippet.wav
# Clip shape: (23040000,), Sample rate: 192000 Hz

# %%
num_boat_unique_passages = snippets_df[snippets_df["context"] == "Boat"]["source_label_passage_id"].nunique()
print(f"Number of unique 'Boat' passages: {num_boat_unique_passages}")
# Out:
# Number of unique 'Boat' passages: 6

# %%
snippets_df["unique_passage_id"] = snippets_df["source_label_passage_id"].astype(str) + "_" + snippets_df["source_label_file"]
num_boat_unique_passages = snippets_df[snippets_df["context"] == "Boat"]["unique_passage_id"].nunique()
print(f"Number of unique 'Boat' passages: {num_boat_unique_passages}")
# Out:
# Number of unique 'Boat' passages: 45

# %%
snippets_df["snippet_duration_s"] = snippets_df["snippet_end_s"] - snippets_df["snippet_start_s"]
snippets_df[snippets_df["context"] == "Boat"]["snippet_duration_s"].sum()/60
# Out:
# 197.83333333333334

# %%
snippets_df.to_csv(f"../data/evaluation_snippets/v2/snippets_df.csv", index=False)

# %% [markdown]
# raven_df = translate_to_raven(results_df, sample_rate)
